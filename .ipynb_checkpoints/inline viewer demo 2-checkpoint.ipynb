# %%
import SpectrumViewer.InlineViewer as inline
# %matplotlib notebook
fileName = 'SpectrumViewer/example_lite.fits'
fileSource = 'SDSS'
inline.view(fileName, fileSource)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import SpectrumViewer.InlineViewer as inline
# %matplotlib notebook
fileName = 'SpectrumViewer/example_lite.fits'
fileSource = 'SDSS'

# %%
from astropy.io import fits
coaddData =1
zData =3
hdulist = fits.open(fileName)
c=hdulist[coaddData].data
z=hdulist[zData].data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ab60c62b48dd> in <module>()
#       2 coaddData =1
#       3 zData =3
# ----> 4 hdulist = fits.open(filename)
#       5 c=hdulist[coaddData].data
#       6 z=hdulist[zData].data
#
# NameError: name 'filename' is not defined
